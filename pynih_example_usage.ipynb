# %% [markdown]
# <a href="https://colab.research.google.com/github/Laura-Ellis/ARD/blob/main/pynih_example_usage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install pynih with pip
# !pip install pynih

# %%
from pynih import apis

# define search criteria
search_criteria ={
        "agencies":["NIAID"],
        "include_active_projects": True
    }

# illustration of project api usage
include_fields = [ "ApplId","SubprojectId","FiscalYear","OrgName","OrgCity", "OrgState","OrgStateName","DeptType", "ProjectNum","OrgCountry" ]
data = apis.query_project_api(include_fields=include_fields,
                              search_criteria=search_criteria,
                              limit=500)

# %%
import pandas as pd
pd.DataFrame(data)
# Out:
#       appl_id subproject_id  fiscal_year        project_num
# 0    10646015          None         2023    1R21AI175731-01
# 1    10674045          None         2023    5R01AI156900-04
# 2    10712455          None         2023  1T32AI170496-01A1
# 3    10682295          None         2023    1R01AI176829-01
# 4    10804373          None         2024  9R01AI178795-09A1
# ..        ...           ...          ...                ...
# 495  10617390          None         2023    5R44AI153011-03
# 496  10650828          None         2023    5R01AI170158-02
# 497  10730832          None         2023    1R15AI178654-01
# 498  10667007          None         2023  1R21AI169111-01A1
# 499  10874033          None         2023  3R21AI171940-02S1
#
# [500 rows x 4 columns]

# %%
apis.query_project_api
# Out:
# <function pynih.apis.query_project_api(include_fields: List[str] = None, search_criteria: Dict[str, str] = {}, limit: int = 1, offset: int = 0) -> List[Dict]>
